# %% [markdown]
# Author: Benny Wai
#
# Update notes:

# %%
import json
import numpy as np
import pandas as pd
import urllib.request
from PIL import Image
import glob

# %% [markdown]
# # Read from json and clean data

# %%
from py_functions.gen_func import read_and_clean
file_location_var = 'raw_data/'
file_name_var = 'srd_5e_monsters.json'

clean_df = read_and_clean(file_location = file_location_var, json_file = file_name_var)

clean_df
# Out:
# C:\Users\benny\projects\d5e_monster\py_functions\gen_func.py:25: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   clean_df = pd.DataFrame(df['name'].str.lower().str.replace(' ','_').str.replace('/','_').str.replace('(','_')
# C:\Users\benny\projects\d5e_monster\py_functions\gen_func.py:26: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   .str.replace(')','_'), columns = ['name'])
#                     name    size        type   ethics moral  \
# 0                aboleth   large  aberration   lawful  evil
# 1                acolyte  medium    humanoid      any   any
# 2     adult_black_dragon    huge      dragon  chaotic  evil
# ...

# %% [markdown]
# # Save images in folder

# %%
from py_functions.gen_func import save_img_from_url

### apply img save function to columns of the df
clean_df.apply(save_img_from_url, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 322    None
# 323    None
# 324    None
# 325    None
# 326    None
# Length: 327, dtype: object

# %% [markdown]
# # Image viewer for convenience

# %%
### image viewer for convenience
Image.open('images/monsters/aboleth.jpeg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x850 at 0x2B55020E048>

# %% [markdown]
# # Check for missing images (as image templates)

# %%
template_list = glob.glob("images/missing_templates/*.jpeg")
monster_list = glob.glob("images/monsters/*.jpeg")

for i in range(len(template_list)):
    display(Image.open(template_list[i]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x2648749AC08>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x26487579188>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x26487579AC8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x26487579AC8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x26487579AC8>

# %%
from py_functions.gen_func import check_for_missing

monster_folder = 'images/monsters/'
template_folder = 'images/missing_templates/'

missing_images_list = check_for_missing(monster_folder,template_folder)
missing_images_list
# Out:
# ['acolyte',
#  'allosaurus',
#  'ankylosaurus',
#  'ape',
#  'awakened_shrub',
#  'awakened_tree',
#  'axe_beak',
#  'baboon',
#  'bandit',
#  'berserker',
#  'black_bear',
#  'blood_hawk',
#  'boar',
#  'brown_bear',
#  'camel',
#  'cat',
#  'commoner',
#  'constrictor_snake',
#  'crab',
#  'crocodile',
#  'deer',
#  'draft_horse',
#  'elephant',
#  'elk',
#  'giant_ape',
#  'giant_bat',
#  'giant_boar',
#  'giant_centipede',
#  'giant_constrictor_snake',
#  'giant_crab',
#  'giant_crocodile',
#  'giant_elk',
#  'giant_goat',
#  'giant_hyena',
#  'giant_lizard',
#  'giant_poisonous_snake',
#  'giant_scorpion',
#  'giant_sea_horse',
#  'giant_shark',
#  'giant_toad',
#  'giant_vulture',
#  'giant_wasp',
#  'giant_weasel',
#  'giant_wolf_spider',
#  'gladiator',
#  'goat',
#  'gray_ooze',
#  'guard',
#  'hunter_shark',
#  'jackal',
#  'killer_whale',
#  'knight',
#  'lion',
#  'lizard',
#  'mage',
#  'mammoth',
#  'mule',
#  'mummy_lord',
#  'panther',
#  'poisonous_snake',
# ...

# %%
len(missing_images_list)/clean_df.shape[0]
# Out:
# 0.24464831804281345

# %%
## manually download missing images - find a better way soon
missing_images_list[4]
# Out:
# 'awakened_shrub'

# %%
## read the monsters from the SRD
with open('raw_data/srd_5e_monsters.json') as f:
  raw_data = json.load(f)

# %%
df = pd.json_normalize(raw_data)

# %%
df
# Out:
#                     name                           meta         Armor Class  \
# 0                Aboleth  Large aberration, lawful evil  17 (Natural Armor)
# 1                Acolyte           Medium humanoid, any                 10
# 2     Adult Black Dragon      Huge dragon, chaotic evil  19 (Natural Armor)
# 3      Adult Blue Dragon       Huge dragon, lawful evil  19 (Natural Armor)
# 4     Adult Brass Dragon      Huge dragon, chaotic good  18 (Natural Armor)
# ..                   ...                            ...                 ...
# 322   Young Green Dragon      Large dragon, lawful evil  18 (Natural Armor)
# 323     Young Red Dragon     Large dragon, chaotic evil  18 (Natural Armor)
# 324  Young Silver Dragon      Large dragon, lawful good  18 (Natural Armor)
# 325   Young White Dragon     Large dragon, chaotic evil  17 (Natural Armor)
# 326               Zombie    Medium undead, neutral evil                  8
#
# ...

# %% [markdown]
# # Clean data

# %%
### clean the name column (replacing spaces with '_'s) and break meta into 4 seperate columns

## get name, lower case and _ between words
clean_df = pd.DataFrame(df['name'].str.lower().str.replace(' ','_').str.replace('/','_').str.replace('(','_').str.replace(')','_'), columns = ['name'])

## split the size and type
clean_df = pd.concat([clean_df,pd.DataFrame(
            pd.DataFrame(
                df['meta'].str.split(', ').tolist()
                , columns = ['creature_info','alignment'])
                    ['creature_info'].str.split(' ').tolist()
                        , columns = ['size','type'])], axis=1)

## create alignment column to be split later, first deal with outliers
clean_df = pd.concat([clean_df,
            pd.DataFrame(pd.DataFrame(
                df['meta'].str.split(', ').tolist()
                , columns = ['creature_info','alignment'])['alignment'])], axis=1)
when_conditions = [clean_df['alignment'] == 'unaligned',clean_df['alignment'] == 'any', clean_df['alignment'] == 'neutral', clean_df['alignment'] == 'any evil alignment']
then_statements = ['unaligned unaligned','any any','neutral neutral','any evil']
clean_df['alignment'] = np.select(when_conditions,then_statements, default=clean_df['alignment'])

## split the alignment column
clean_df = pd.concat([clean_df,
            pd.DataFrame(
                clean_df['alignment'].str.split(' ').tolist()
                , columns = ['ethics','moral'])], axis=1)
clean_df = clean_df.drop(['alignment'], axis = 1)

## lower case all current columns
clean_df = clean_df.apply(lambda x: x.astype(str).str.lower())

clean_df = pd.concat([clean_df,df.drop(['name','meta'],axis=1)],axis=1)
clean_df
# Out:
# C:\Users\benny\miniconda3\envs\d5e_monster_venv\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.
#                     name    size        type   ethics moral  \
# 0                aboleth   large  aberration   lawful  evil
# 1                acolyte  medium    humanoid      any   any
# 2     adult_black_dragon    huge      dragon  chaotic  evil
# 3      adult_blue_dragon    huge      dragon   lawful  evil
# 4     adult_brass_dragon    huge      dragon  chaotic  good
# ..                   ...     ...         ...      ...   ...
# 322   young_green_dragon   large      dragon   lawful  evil
# 323     young_red_dragon   large      dragon  chaotic  evil
# 324  young_silver_dragon   large      dragon   lawful  good
# ...

# %%
### define function for saving images into folder
def save_img_from_url(x):
    urllib.request.urlretrieve(x['img_url'], "images/monsters/"+x['name']+".jpeg")

# %%
### apply img save function to columns of the df
clean_df.apply(save_img_from_url, axis=1)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 322    None
# 323    None
# 324    None
# 325    None
# 326    None
# Length: 327, dtype: object

# %%
template_list = glob.glob("images/missing_templates/*.jpeg")

# %%
### get template of 
template_list = glob.glob("images/missing_templates/*.jpeg")

# %%
template_list = glob.glob("images/missing_templates/*.jpeg")
monster_list = glob.glob("images/monsters/*.jpeg")

template_status = False

for i in range(len(template_list)):
    display(Image.open(template_list[i]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x205C6E73B88>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x205C6E06B88>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x205C6E045C8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x205C6E04FC8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x205C6E06B88>

# %%
for i in range(len(template_list)):
    display(Image.open(template_list[i]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x13BA9DC4D48>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x13BA9DBE048>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x13BA9DBE0C8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x13BA9DBE4C8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250 at 0x13BA9DBE508>

# %%
open("images/monsters/aboleth.jpeg","rb").read() == open("images/monsters/aboleth.jpeg","rb").read()
# Out:
# True

# %%
### image viewer for convenience
Image.open('images/monsters/aboleth.jpeg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x850 at 0x13BA9D15248>

# %%
var1 = clean_df['name'].str.contains('suc')
clean_df[var1]
#clean_df.loc[325,'img_url']
# Out:
#                  name    size   type   ethics moral         Armor Class  \
# 274  succubus/incubus  medium  fiend  neutral  evil  15 (Natural Armor)
#
#          Hit Points                Speed STR STR_mod  ...     Challenge  \
# 274  66 (12d8 + 12)  30 ft., fly 60 ft.    8    (-1)  ...  4 (1,100 XP)
#
#                                                 Traits  \
# 274  <p><em><strong>Telepathic Bond.</strong></em> ...
#
#                                                Actions Legendary Actions  \
# 274  <p><em><strong>Claw (Fiend Form Only).</strong...               NaN
#
#                                                img_url Damage Immunities  \
# 274  https://media-waterdeep.cursecdn.com/avatars/t...               NaN
#
#     Condition Immunities                                 Damage Resistances  \
# 274                  NaN  Cold, Fire, Lightning, Poison; Bludgeoning, Pi...
#
#     Damage Vulnerabilities Reactions
# 274                    NaN       NaN
#
# [1 rows x 34 columns]

# %%
clean_df.loc[274,'img_url']
# Out:
# 'https://media-waterdeep.cursecdn.com/avatars/thumbnails/0/103/315/315/636252742573312994.jpeg'

# %%
clean_df
# Out:
#                     name    size        type   ethics moral  \
# 0                aboleth   large  aberration   lawful  evil
# 1                acolyte  medium    humanoid      any   any
# 2     adult_black_dragon    huge      dragon  chaotic  evil
# 3      adult_blue_dragon    huge      dragon   lawful  evil
# 4     adult_brass_dragon    huge      dragon  chaotic  good
# ..                   ...     ...         ...      ...   ...
# 322   young_green_dragon   large      dragon   lawful  evil
# 323     young_red_dragon   large      dragon  chaotic  evil
# 324  young_silver_dragon   large      dragon   lawful  good
# 325   young_white_dragon   large      dragon  chaotic  evil
# 326               zombie  medium      undead  neutral  evil
#
#             Armor Class         Hit Points  \
# 0    17 (Natural Armor)   135 (18d10 + 36)
# 1                   10             9 (2d8)
# 2    19 (Natural Armor)   195 (17d12 + 85)
# 3    19 (Natural Armor)  225 (18d12 + 108)
# ...

# %%
clean_df.shape
# Out:
# (327, 34)

# %%
var1 = clean_df['size'] == 'bob'
clean_df[var1].shape[0]
# Out:
# 0

# %%
if clean_df is None:
    print("hi")

# %%
urllib.request.urlretrieve(clean_df.loc[0,'img_url'], "monster_images/"+clean_df.loc[0,'name']+".jpeg")
# Out:
# ('monster_images/aboleth.jpeg', <http.client.HTTPMessage at 0x20be8040d08>)

# %%
clean_df.loc[0,'img_url']
# Out:
# 'https://media-waterdeep.cursecdn.com/avatars/thumbnails/0/11/1000/1000/636238825975375671.jpeg'

# %%
clean_df.loc[0,'name']
# Out:
# 'aboleth'

# %%
clean_df['type'].value_counts()
# Out:
# beast          95
# dragon         43
# humanoid       40
# monstrosity    40
# fiend          23
# undead         20
# elemental      16
# giant          11
# construct       9
# plant           7
# aberration      7
# fey             6
# celestial       6
# ooze            4
# Name: type, dtype: int64

# %%
clean_df[0:5]['img_url'].apply(lambda x: urllib.request.urlretrieve(clean_df.loc[0,'img_url'], "monster_images/"+clean_df.loc[0,'name']+".jpeg"))
# Out:
# 0    https://media-waterdeep.cursecdn.com/avatars/t...
# 1    https://media-waterdeep.cursecdn.com/attachmen...
# 2    https://media-waterdeep.cursecdn.com/avatars/t...
# 3    https://media-waterdeep.cursecdn.com/avatars/t...
# 4    https://media-waterdeep.cursecdn.com/avatars/t...
# Name: img_url, dtype: object

# %%
im = Image.open('withmed.jpg',0)

# %%
pd.DataFrame(df['meta'].str.split(', ',0).tolist(), columns = ['creature_info','alignment'])['alignment'].value_counts()
# Out:
# unaligned             125
# chaotic evil           46
# lawful evil            37
# neutral evil           28
# any                    23
# neutral                22
# lawful good            19
# chaotic good           12
# neutral good            6
# lawful neutral          4
# chaotic neutral         4
# any evil alignment      1
# Name: alignment, dtype: int64

# %%
pd.DataFrame(pd.DataFrame(
                df['meta'].str.split(', ').tolist()
                , columns = ['creature_info','alignment'])['alignment'])
# Out:
#         alignment
# 0     lawful evil
# 1             any
# 2    chaotic evil
# 3     lawful evil
# 4    chaotic good
# ..            ...
# 322   lawful evil
# 323  chaotic evil
# 324   lawful good
# 325  chaotic evil
# 326  neutral evil
#
# [327 rows x 1 columns]

# %%
df['name'].str.lower()
# Out:
# 0                  aboleth
# 1                  acolyte
# 2       adult black dragon
# 3        adult blue dragon
# 4       adult brass dragon
#               ...
# 322     young green dragon
# 323       young red dragon
# 324    young silver dragon
# 325     young white dragon
# 326                 zombie
# Name: name, Length: 327, dtype: object

# %%
pd.DataFrame(
    pd.DataFrame(
        df['meta'].str.split(', ').tolist()
        , columns = ['creature_info','alignment'])
            ['creature_info'].str.split(' ').tolist()
                , columns = ['size','type'])
# Out:
#        size        type
# 0     Large  aberration
# 1    Medium    humanoid
# 2      Huge      dragon
# 3      Huge      dragon
# 4      Huge      dragon
# ..      ...         ...
# 322   Large      dragon
# 323   Large      dragon
# 324   Large      dragon
# 325   Large      dragon
# 326  Medium      undead
#
# [327 rows x 2 columns]

# %%
pd.DataFrame(df['meta'].str.split(', ',0).tolist(), columns = ['creature_info','alignment'])['alignment'].value_counts()
# Out:
# unaligned             125
# chaotic evil           46
# lawful evil            37
# neutral evil           28
# any                    23
# neutral                22
# lawful good            19
# chaotic good           12
# neutral good            6
# lawful neutral          4
# chaotic neutral         4
# any evil alignment      1
# Name: alignment, dtype: int64

# %%
df['meta']
# Out:
# 0      Large aberration, lawful evil
# 1               Medium humanoid, any
# 2          Huge dragon, chaotic evil
# 3           Huge dragon, lawful evil
# 4          Huge dragon, chaotic good
#                    ...
# 322        Large dragon, lawful evil
# 323       Large dragon, chaotic evil
# 324        Large dragon, lawful good
# 325       Large dragon, chaotic evil
# 326      Medium undead, neutral evil
# Name: meta, Length: 327, dtype: object
